# %% [markdown]
# <a href="https://colab.research.google.com/github/BrayanCharlesEtec/Fluxogramas/blob/main/TemP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Q1**

# %%
#entrada
p1=9.2
p2=8.7

#processamento
media=(p1+p2)/2

#saída
print(media)
# Out:
# 8.95

# %% [markdown]
# ![i1.png](data:image/png;base64,...)
#
# ![i![i2.png](data:image/png;base64,...![i8m.png](data:image/png;base64,...![i1f.png](data:image/png;base64,...![i2.png](data:image/png;base64,...![i2 (1).png](data:image/png;base64,...)))))1f.png](data:image/png;base64,...)

# %% [markdown]
# # **Q2**

# %%
#entrada
dolar = float(input("Digete a cotação do dólar hoje: "))
valor = float(input("Digete o valor em real que deseja converter em Dólar: "))
# Out:
# Digete a cotação do dólar hoje: 60
# Digete o valor em real que deseja converter em Dólar: 6000

# %%
#processamento
resp = valor/dolar

# %%
print("Olá  você converteu R$", valor, "em dólar, o resultado é; $" , resp )
# Out:
# Olá  você converteu R$ 6000.0 em dólar, o resultado é; $ 100.0

# %% [markdown]
# # **Q3**

# %%
#entrada
n1 = float(input("Digete o valor: "))
n2 = float(input("Digete o valor: "))
n3 = float(input("Digete o valor: "))
n4 = float(input("Digete o valor: "))

#processamento
total = (n1**2)+(n2**2)+(n1**2)+ (n4**2)


#saída
print(total)
# Out:
# Digete o valor: 7
# Digete o valor: 4
# Digete o valor: 2
# Digete o valor: 8
# 178.0

# %% [markdown]
# # **Q4**

# %%
#entrada
p = float(input("Digete o valor das peças R$: "))
q = float(input("Digete a quantiade de peças: "))

#processamento
t =(p*q)
total = (t*5)/100

#saida
print(total)
# Out:
# Digete o valor das peças R$: 6
# Digete a quantiade de peças: 7
# 2.1

# %% [markdown]
# # **Q5**

# %%
#entarda
c = float(input("Digete o valor do carro: "))

#processamento
i = (c*45)/100
d = (i+c)*28/100
t = (i+d+c)


#saida
print(t)
# Out:
# Digete o valor do carro: 1500
# 2784.0

# %% [markdown]
# # **Q6**

# %%
#entrada
horas = float(input("Digete as horas: "))
minutos = float(input("Digete os minutos: "))

#processamento
total = horas* 3600 + minutos *60

#saida
print("total de segundos :", total)
# Out:
# Digete as horas: 70
# Digete os minutos: 40
# total de segundos : 254400.0

# %% [markdown]
# # **Q7**

# %%
#entrada
horas = float(input("Digete as horas trabalhadas: "))
minutos = float(input("Digete os minutos trabalhados: "))
sph = float(input("Digete o salario por hora: "))

#processamentos
horas += minutos/60
total = sph * horas *1.7


#saida
print("o funcionario vai ganhar R$ :", total ,"pelas horas extras")
# Out:
# Digete as horas trabalhadas: 30
# Digete os minutos trabalhados: 600
# Digete o salario por hora: 40
# o funcionario vai ganhar R$ : 2720.0 pelas horas extras

# %% [markdown]
# # **Q8**

# %%
#entrada
kmp = float(input("Digete a quantidade de Km a percorrer: "))
gasolina = float(input("Digete o consumo de gasolina do carro (em km/h): "))
preco = float(input("Digete o preço medio da gasolina: "))

#processamento
t = (kmp/gasolina)
c = (t*preco)
 #saida
print("para percorrer KM ", kmp ,"sera nessecario R$", c )
# Out:
# Digete a quantidade de Km a percorrer: 40
# Digete o consumo de gasolina do carro (em km/h): 20
# Digete o preço medio da gasolina: 50
# para percorrer KM  40.0 sera nessecario R$ 100.0

# %%
#entrada
vm = 110
distancia = float(input("Digete a distancia percorrida em quilometros: "))
tempo = float(input("Digete o tempo gasto em horas: "))

 #processamento
t = (distancia/tempo)

 #saida
print("a velocicidade media foi" ,t ,"KM/H")
# Out:
# Digete a distancia percorrida em quilometros: 4
# Digete o tempo gasto em horas: 400
# a velocicidade media foi 0.01 KM/H
